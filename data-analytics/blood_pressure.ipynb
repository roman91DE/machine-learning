# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from re import match

# %%
dbs = !ls *.csv
for db in dbs:
    if match("^blood_pressure*", db):
        path = db

# %%
df = pd.read_csv(path, index_col=0)
df
# Out:
#             sex agegrp  bp_before  bp_after
# patient
# 1          Male  30-45        143       153
# 2          Male  30-45        163       170
# 3          Male  30-45        153       168
# 4          Male  30-45        153       142
# 5          Male  30-45        146       141
# ...         ...    ...        ...       ...
# 116      Female    60+        152       152
# 117      Female    60+        161       152
# 118      Female    60+        165       174
# 119      Female    60+        149       151
# 120      Female    60+        185       163
#
# [120 rows x 4 columns]

# %%
df.describe()
# Out:
#         bp_before    bp_after
# count  120.000000  120.000000
# mean   156.450000  151.358333
# std     11.389845   14.177622
# min    138.000000  125.000000
# 25%    147.000000  140.750000
# 50%    154.500000  149.500000
# 75%    164.000000  161.000000
# max    185.000000  185.000000

# %%
fig, ((ax00, ax01),(ax10, ax11)) = plt.subplots(nrows=2, ncols=2, figsize=[2 * 6.4, 2 * 4.8])

fig.suptitle("Blood Pressure", size=24)

ax00.pie(df.groupby("sex").size(), labels=np.unique(df["sex"]))
ax00.set_title("Sex Distribution", loc="left")

ax01.hist(df["agegrp"], histtype="stepfilled")
# Out:
# (array([40.,  0.,  0.,  0.,  0., 40.,  0.,  0.,  0., 40.]),
#  array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. ]),
#  [<matplotlib.patches.Polygon at 0x7fb8d096e1d0>])

# %%
ax01.hist?

# %%
a = np.arange(0,16,2)
print(a.shape)
print(a)

b = np.arange(0,16,2)[: ,None]
print(b.shape)
print(b)

print(a+b)
# Out:
# (8,)
# [ 0  2  4  6  8 10 12 14]
# (8, 1)
# [[ 0]
#  [ 2]
#  [ 4]
#  [ 6]
#  [ 8]
#  [10]
#  [12]
#  [14]]
# [[ 0  2  4  6  8 10 12 14]
#  [ 2  4  6  8 10 12 14 16]
#  [ 4  6  8 10 12 14 16 18]
#  [ 6  8 10 12 14 16 18 20]
#  [ 8 10 12 14 16 18 20 22]
#  [10 12 14 16 18 20 22 24]
#  [12 14 16 18 20 22 24 26]
#  [14 16 18 20 22 24 26 28]]

# %%
np.newaxis?
