# %%
import numpy as np
import matplotlib as mpl
from matplotlib import pyplot as plt

# %% [markdown]
# # Diagramme
# 1. Angebot & Nachfrage

# %%
def f(x, m, b):
    return (m * x) + b

# %%
# model parameters
p_min, p_max = 1, 100
x_min, x_max = 0, 100

prices = np.linspace(p_min, p_max, (p_max - p_min))

x = np.linspace(
    0,
    max(xs(p_max, preference_coef), xd(p_min, preference_coef)),
    (p_max - p_min)
)

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)

for axe in axes:
    axe.set_xlabel("Menge in Stück")
    axe.set_ylabel("Preis in EUR")

axes[0].plot(xs(prices, preference_coef), prices, label="Angebot")
axes[1].plot(xd(prices, preference_coef), prices, label="Nachfrage")



axes[0].legend()
axes[1].legend()
