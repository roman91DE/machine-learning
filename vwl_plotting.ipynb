# %% [markdown]
# # Microeconomics

# %%
import numpy as np
import matplotlib as mpl
from matplotlib import pyplot as plt

# %% [markdown]
# ## Linear model
#
# ### Linear function
# > $$ p=m * x + b $$
#
# ### Slope
# > $$ m = \delta {p} - \delta {x} = \frac {(p_2 - p_1)} {(x_2 - x_1)} $$

# %%
def p(x, m, b):
    return (m * x) + b

def m(x1, x2, p1, p2):
    return ((p2 - p1) / (x2 - x1))

# %%
# model parameters
env = {
    "p_min": 0,
    "p_max": 1000,
    "x_min": 0,
    "x_max": 1000
    }


# functions: f(quantity) -> price
def supply(x):
    return p(
        x,
        m(env["x_min"], env["x_max"], env["p_min"], env["p_max"]),
        env["p_min"]
    )

def demand(x):
    return p (
        x,
        m(env["x_min"], env["x_max"], env["p_max"], env["p_min"]),
        env["p_max"]
    )
    
# plotting ranges
prices = np.linspace(
    env["p_min"], env["p_max"], (env["p_max"] - env["p_min"])
    )
x = np.linspace(
    env["x_min"], env["x_max"], (env["x_max"] - env["x_min"])
    )

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)

for axe in axes:
    axe.set_xlabel("Menge [Stück]")
    axe.set_ylabel("Preis [EUR]")

axes[0].plot(prices, supply(prices), label="Angebot")
axes[1].plot(prices, demand(prices), label="Nachfrage")

axes[0].legend()
axes[1].legend()

# %%
fig, ax = plt.subplots()

ax.set_xlabel("Menge [Stück]")
ax.set_ylabel("Preis [EUR]")

ax.plot(prices, supply(prices), label="Angebot")
ax.plot(prices, demand(prices), label="Nachfrage")

ax.legend()

# %% [markdown]
# ## Equilibrium

# %%
fig, ax = plt.subplots()

ax.plot(prices, supply(prices), label="Angebot")
ax.plot(prices, demand(prices), label="Nachfrage")

pmean = np.full(len(prices), np.mean(prices))
xmean = np.full(len(x), np.mean(x))

ax.plot(prices, xmean)
ax.plot(pmean, x)

ax.legend()

# %% [markdown]
# # Cobb Douglas Nutzenfunktion
#
# ### Utility function:
#
# > $$U(x_1, x_2)=x_1^{\alpha} * x_2^{(1-\alpha)}$$
#
# ### Budget restriction:
#
# > $$b = x_1 * p_1 + x_2 * p_2$$

# %%
# model parameters
env = {
    "alpha": 0.6,
    "p_1": 1,
    "p_2": 2,
    "b": 200
}

def U(x_1, x_2, env):
    return (x_1 ** env["alpha"]) * (x_2 ** env["alpha"])

def b():
    return

# %%
from mpl_toolkits.mplot3d import Axes3D  
# %matplotlib inline

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

x1_max = (env["b"] / env["p_1"])
x2_max = (env["b"] / env["p_2"])

x1_vals = np.linspace(0, x1_max)
x2_vals = np.linspace(0, x2_max)
U = U(X1, X2, env)

X1, X2 = np.meshgrid(x1_vals, x2_vals) 
ax.plot_surface(X1, X2, U)

ax.set_xlabel('x1')
ax.set_ylabel('x2')
ax.set_zlabel('U(x1, x2)')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/y9/7jjjsfc109bd1vq47cyqxxlh0000gn/T/ipykernel_4696/1693591449.py in <module>
#       7 x1_vals = np.linspace(0, x1_max)
#       8 x2_vals = np.linspace(0, x2_max)
# ----> 9 U = U(X1, X2, env)
#      10
#      11 X1, X2 = np.meshgrid(x1_vals, x2_vals)
#
# TypeError: 'numpy.ndarray' object is not callable

# %%
import numpy as np
from mpl_toolkits.mplot3d import Axes3D  
# Axes3D import has side effects, it enables using projection='3d' in add_subplot
import matplotlib.pyplot as plt
import random

def fun(x, y):
    return x**2 + y

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
x = y = np.arange(-3.0, 3.0, 0.05)
X, Y = np.meshgrid(x, y)
zs = np.array(fun(np.ravel(X), np.ravel(Y)))
Z = zs.reshape(X.shape)

ax.plot_surface(X, Y, Z)

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

plt.show()

3d
